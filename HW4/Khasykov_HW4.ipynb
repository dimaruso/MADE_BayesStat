# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

from decoding import FreqDecoder, MCMCDecoder
from utils import *

# %%
PATH_TO_CORPORA_FOLDER = "./corpora"

# %% [markdown]
# Определим тестовый текст для алгоритмов дешифровки:

# %%
# Отрывок из "Одноэтажная Америка" (Ильф и Петров)
TEST_TEXT_IN_RUSSIAN = """
     Процесс еды был так же превосходно рационализирован,  как  производство
    автомобилей или пишущих машинок. - Еще дальше кафетерий по этому пути  пошли
    автоматы. Имея примерно ту же внешность, что и кафетерии, они довели процесс
    проталкивания пищи в американские желудки до  виртуозности.  Стены  автомата
    сплошь  заняты  стеклянными  шкафчиками.  Возле  каждого  из  них  щель  для
    опускания "никеля" (пятицентовой монеты). За стеклом печально стоит  тарелка
    с супом, или мясом, или стакан с соком, или  пирог.  Несмотря  на  сверкание
    стекла и металла, лишенные свободы сосиски  и  котлеты  производят  какое-то
    странное впечатление. Их жалко, как  кошек  на  выставке.  Человек  опускает
    никель, получает возможность отворить дверцу, вынимает  суп,  несет  его  на
    свой столик и там съедает, опять-таки положив шляпу под стул на  специальную
    жердочку. Потом человек подходит к крану, опускает  никель,  и  из  крана  в
    стакан течет ровно столько кофе с молоком, сколько полагается. Чувствуется в
    этом что-то обидное, оскорбительное для человека. Начинаешь подозревать, что
    хозяин автомата  оборудовал  свое  заведение  не  для  того,  чтобы  сделать
    обществу приятный сюрприз, а чтобы уволить со службы бедных завитых  девушек
    в розовых наколках и заработать еще больше долларов.
"""

# %% [markdown]
# Чтение референсного текста:

# %%
path_to_war_and_piece_text_rus = os.path.join(PATH_TO_CORPORA_FOLDER, "WarAndPeace.txt")

with open(path_to_war_and_piece_text_rus, "r") as f:
    war_and_piece_text_rus = f.read()

# %% [markdown]
# Приведение текстов к нормализованному виду:
#     - lowercase
#     - удаление пунктуации

# %%
reference_text_rus = preprocess_text(war_and_piece_text_rus, RUSSIAN_ALPHABET)
test_text_in_russian = preprocess_text(TEST_TEXT_IN_RUSSIAN, RUSSIAN_ALPHABET)

# %% [markdown]
# Кодирование тестового текста

# %%
encoded_test_text_in_russian = encode_text(test_text_in_russian)

# %% [markdown]
# ## Пункт 1. Базовый частотный метод по Шерлоку Холмсу (униграммы)

# %% [markdown]
# Расшифровка закодированного тестового текста с помощью униграмм:

# %%
unigram_decoder = FreqDecoder.init_decoder_with_reference_text(text=reference_text_rus, token_len=1)
decoded_text = unigram_decoder.decode(encoded_test_text_in_russian)
rate_of_matched_letters = estimate_rate_of_matched_letters(test_text_in_russian, decoded_text)
print(decoded_text)
print()
print(f"rate_of_matched_letters: {rate_of_matched_letters}")
# Out:
# кдошасс амг бгл еит жа кдаросйомво дишновилнындорив тит кдоныромсеро иреоуобнлаю нлн кнчпхнй уичнвот аха миляча тиэаеадню ко щеоуп кпен кочлн иреоуиег нуаь кднуадво еп жа рвачвосея зео н тиэаеаднн овн моралн кдошасс кдоеилтнривнь кнхн р иуаднтивстна жалпмтн мо рндепоывосен сеавг иреоуиеи склочя ыивьег сеатльввгун чтиэзнтиун роыла тижмоцо ны внй халя мль окпстивнь внталь кьеншавеорою уоваег ыи сеатлоу казиляво сеоне еидалти с спкоу нлн уьсоу нлн сеитив с сотоу нлн кндоц васуоедь ви срадтивна сеатли н уаеилли лнчаввга сробомг соснстн н тоелаег кдоныромье титоа ео седиввоа рказиелавна нй жилто тит точат ви ргсеирта залорат окпстиае внталя колпзиае роыуожвосея оероднея мрадшп ргвнуиае спк васае ацо ви срою сеолнт н еиу сёамиае окьея еитн коложнр члькп ком сепл ви скашнилявпф жадмозтп коеоу залорат комйомне т тдивп окпстиае внталя н ны тдиви р сеитив еазае дорво сеолято тоэа с уолотоу столято колициаесь зпрсерпаесь р щеоу зео ео обнмвоа остодбнеалявоа мль залорати визнвиачя комоыдариея зео йоыьнв иреоуиеи ободпморил сроа ыирамавна ва мль еоцо зеобг смалиея обхасерп кдньевгю сфдкдны и зеобг пролнея со слпжбг бамвгй ыирнегй марпчат р доыоргй витолтий н ыидибоеиея аха боляча моллидор
#
# rate_of_matched_letters: 0.35845896147403683

# %% [markdown]
# При данном способе расшифровки получилось угадать примерно треть букв. Результат дешифровки нечитаем.

# %% [markdown]
# ## Пункт 2. Биграммы

# %% [markdown]
# Расшифровка закодированного тестового текста с помощью биграмм:

# %%
bigram_decoder = FreqDecoder.init_decoder_with_reference_text(text=reference_text_rus, token_len=2)
decoded_text = bigram_decoder.decode(encoded_test_text_in_russian)
rate_of_matched_letters = estimate_rate_of_matched_letters(test_text_in_russian, decoded_text)
print(decoded_text)
print()
print(f"rate_of_matched_letters: {rate_of_matched_letters}")
# Out:
# олкрн одавй чтимсткаю и трь ошотподиужвшон бз л тиег вкаоламихот нь омсьгоределыто би окще л злунуивесвиниладне  в эли мвевогл пчии паа воожа ел пда утоин доледвапоензаю раем хиллоу  птонаки овандроконим ала олкрн одолсклажетико двыизраомин м вжижее ю кнд а рираариеогпо на  нойй ел пдасто цепея мооп уо лихоывбыулым вехатейа ь жне  вьнму сть и л шаля эт дныча вко дкос т и доньой пь веакем ует к норанв адое тпоо  птеенбеал во о сагото б зекгото бо ст вегодобнев деа выл укемсмскаш и ксява вкое  нормито з оламиахокойбые сяреотй обаг ча а неят ой оламихотдонаосльен с ны ылльраадоеятойрутопрьех  с вканеазкаонрадвстече всан гканыча в о иаталя вокное ораогакялиллороняудтея ьсвагдраяседк ерийуземаеерых соно ь ве новаттоенейо люси орорылоеноса воан флеожгизавотс нрь и кзнвулк тлсаюю ысгубли скгоу алм ори отаязверкагрнозаныча в о иаталя а тьнаы онрао ст вегливсерл ия с новвн сне эо  зовивгоо не тнеи овсск жа доюачняапжа дледугоу  пен среешпое илнесутеалдрльнит у алм ор конееон яя вориплистая ас саяучнуомсьгота креудязм лао ь е мо глякое емнит енму сасрей иралтая реви нтуи  мдобывесёйс мше касрей очовтея обо кнртй фимаидетелтеидниисждоррадиогм ид иосов впра моы  астлоесвинновдне риусбем
#
# rate_of_matched_letters: 0.10134003350083752

# %% [markdown]
# В данном случае получилось еще хуже, т.к. длина тестового текста слишком мала, и частоты биграмм в ней нерепрезентативны относительно их "истинной" частотности в языке.

# %% [markdown]
# ## Пункт 3. MCMC

# %% [markdown]
# В данном пункте при построении и использовании алгоритма MCMC для дешифровки я повторяю логику из Главы 2 работы [[Chen, 2012]](https://link.springer.com/article/10.1007/s11222-011-9232-5).

# %%
mcmc_decoder = MCMCDecoder.init_decoder_with_reference_text(text=reference_text_rus, token_len=2)
decoded_text = mcmc_decoder.decode(
    target_text=encoded_test_text_in_russian, 
    n_draws=20_000,
    scaling_factor=2.0,
    verbose=5_000,
    early_stopping_rounds=5_000,
)
# Out:
# step_number: 0
# likelihood: 5741.478515625
# зжоядууедф еи шеьцчеэдезждноуъофюоежцяйоюцшйлйжонцюечцчезжойлнофуьноецньобоийшдтейшйезйкрёйъебцкйюочедёдефцшхкдечцмдьджйтезоеаьобрезрьйезокшйецньобць ейбдвезжйбджюоеьреэденюдкюоуьхесьоейечцмдьджййеоюйефондшйезжоядууезжоьцшчйнцюйвезйёйенецбджйчцюучйдеэдшрфчйефоенйжьролюоуьйеуьдю ецньобцьцеузшокхелцювь еуьдчшвюю бйекчцмсйчцбйенолшдечцэфощоейлеюйъеёдшхефшвеозручцюйвеюйчдшвезвьйядюьонотебоюдь елцеуьдчшобездсцшхюоеуьойьеьцждшчцеуеурзобейшйебвуобейшйеуьцчцюеуеуочобейшйезйжощеюдубоьжвеюцеунджчцюйдеуьдчшцейебдьцшшцешйкдюю деуноиоф еуоуйучйейечоьшдь езжойлнофвьечцчодеьоеуьжцююоденздсцьшдюйдейъеэцшчоечцчечокдчеюцен уьцнчдесдшондчеозручцдьеюйчдшхезошрсцдьенолбоэюоуьхеоьножйьхефнджярен юйбцдьеурзеюдудьедщоеюцеунотеуьошйчейеьцбеуыдфцдьеозвьхеьцчйезошоэйнекшвзрезофеуьршеюцеуздяйцшхюрпеэджфосчрезоьобесдшондчезофъофйьечечжцюреозручцдьеюйчдшхейейлечжцюценеуьцчцюеьдсдьежонюоеуьошхчоечомдеуебошочобеучошхчоезошцщцдьувесрнуьнрдьувенеаьобесьоеьоеоийфюодеоучожийьдшхюодефшвесдшондчцеюцсйюцдкхезофолжднцьхесьоеъолвйюецньобцьцеоиожрфонцшеуноделцндфдюйдеюдефшвеьощоесьои еуфдшцьхеоиёдуьнрезжйвью теупжзжйлецесьои ерношйьхеуоеушрэи еидфю ъелцнйь ъефднркдченежолон ъеюцчошчцъейелцжциоьцьхедёдеиошхкдефошшцжон
#
#
# step_number: 5000
# likelihood: 11103.7314453125
# броцесс еды пыл так же бревосходно рационализирован как броизводство автомопилей или бишущих машинок еще дальше каюетерий бо этому бути бошли автоматы имея бримерно ту же внешность что и каюетерии они довели броцесс броталкивания бищи в американские желудки до виртуозности стены автомата сблошь заняты стеклянными шкаючиками возле каждофо из них щель для обускания никеля бятицентовой монеты за стеклом бечально стоит тарелка с субом или мясом или стакан с соком или бироф несмотря на сверкание стекла и металла лишенные своподы сосиски и котлеты броизводят какое то странное вбечатление их жалко как кошек на выставке человек обускает никель болучает возможность отворить дверцу вынимает суб несет ефо на свой столик и там съедает обять таки боложив шлябу бод стул на сбециальнуё жердочку ботом человек бодходит к крану обускает никель и из крана в стакан течет ровно столько коюе с молоком сколько болафается чувствуется в этом что то опидное оскорпительное для человека начинаешь бодозревать что хозяин автомата опорудовал свое заведение не для тофо чтопы сделать опществу бриятный сёрбриз а чтопы уволить со служпы педных завитых девушек в розовых наколках и зарапотать еще польше долларов
#
#
# step_number: 10000
# likelihood: 11184.056640625
# процесс еды был так же превосходно рационализирован как производство автомобилей или пишущих машинок еще дальше каюетерий по этому пути пошли автоматы имея примерно ту же внешность что и каюетерии они довели процесс проталкивания пищи в американские желудки до виртуозности стены автомата сплошь заняты стеклянными шкаючиками возле каждофо из них щель для опускания никеля пятицентовой монеты за стеклом печально стоит тарелка с супом или мясом или стакан с соком или пироф несмотря на сверкание стекла и металла лишенные свободы сосиски и котлеты производят какое то странное впечатление их жалко как кошек на выставке человек опускает никель получает возможность отворить дверцу вынимает суп несет ефо на свой столик и там съедает опять таки положив шляпу под стул на специальнуё жердочку потом человек подходит к крану опускает никель и из крана в стакан течет ровно столько коюе с молоком сколько полафается чувствуется в этом что то обидное оскорбительное для человека начинаешь подозревать что хозяин автомата оборудовал свое заведение не для тофо чтобы сделать обществу приятный сёрприз а чтобы уволить со службы бедных завитых девушек в розовых наколках и заработать еще больше долларов
#
#
# MCMC is stopped: score hasn't been improved for 5000 steps

# %% [markdown]
# #### Итоговая расшифровка и % угаданных символов

# %%
rate_of_matched_letters = estimate_rate_of_matched_letters(test_text_in_russian, decoded_text)
print(decoded_text)
print()
print(f"rate_of_matched_letters: {rate_of_matched_letters}")
# Out:
# процесс еды был так же превосходно рационализирован как производство автомобилей или пишущих машинок еще дальше каюетерий по этому пути пошли автоматы имея примерно ту же внешность что и каюетерии они довели процесс проталкивания пищи в американские желудки до виртуозности стены автомата сплошь заняты стеклянными шкаючиками возле каждофо из них щель для опускания никеля пятицентовой монеты за стеклом печально стоит тарелка с супом или мясом или стакан с соком или пироф несмотря на сверкание стекла и металла лишенные свободы сосиски и котлеты производят какое то странное впечатление их жалко как кошек на выставке человек опускает никель получает возможность отворить дверцу вынимает суп несет ефо на свой столик и там съедает опять таки положив шляпу под стул на специальнуё жердочку потом человек подходит к крану опускает никель и из крана в стакан течет ровно столько коюе с молоком сколько полафается чувствуется в этом что то обидное оскорбительное для человека начинаешь подозревать что хозяин автомата оборудовал свое заведение не для тофо чтобы сделать обществу приятный сёрприз а чтобы уволить со службы бедных завитых девушек в розовых наколках и заработать еще больше долларов
#
# rate_of_matched_letters: 0.990787269681742

# %% [markdown]
# С помощью MCMC получилось добиться практически идеальной расшифровки.

# %% [markdown]
# ## Пункт 4. Расшифровка сообщения

# %%
TEXT_TO_DECODE = (
    "←⇠⇒↟↹↷⇊↹↷↟↤↟↨←↹↝⇛⇯↳⇴⇒⇈↝⇊↾↹↟⇒↟↹⇷⇛⇞↨↟↹↝⇛⇯↳⇴⇒⇈↝⇊↾↹↨←⇌⇠↨↹⇙↹⇸↨⇛↙⇛↹⇠⇛⇛↲⇆←↝↟↞↹⇌⇛↨⇛⇯"
    "⇊↾↹⇒←↙⇌⇛↹⇷⇯⇛⇞↟↨⇴↨⇈↹⇠⇌⇛⇯←←↹↷⇠←↙⇛↹↷⇊↹↷⇠←↹⇠↤←⇒⇴⇒↟↹⇷⇯⇴↷↟⇒⇈↝⇛↹↟↹⇷⇛⇒⇙⇞↟↨←↹↳⇴⇌⇠↟↳⇴⇒⇈"
    "↝⇊↾↹↲⇴⇒⇒↹⇰⇴↹⇷⇛⇠⇒←↤↝←←↹⇞←↨↷←⇯↨⇛←↹⇰⇴↤⇴↝↟←↹⇌⇙⇯⇠⇴↹↘⇛↨↞↹⇌⇛↝←⇞↝⇛↹↞↹↝↟⇞←↙⇛↹↝←↹⇛↲←⇆⇴⇏"
)

# %%
mcmc_decoder = MCMCDecoder.init_decoder_with_reference_text(text=reference_text_rus, token_len=2)
decoded_text = mcmc_decoder.decode(
    target_text=TEXT_TO_DECODE, 
    n_draws=10_000,
    scaling_factor=2.0,
    verbose=2_000,
    early_stopping_rounds=2_000,
)
# Out:
# step_number: 0
# likelihood: 1397.2528076171875
# амыщоуюоущхщьаожшзиеысжютощыщоэшвьщожшзиеысжютоьадмьо обьшяшомшшйфажщнодшьшзютоыаядшоэзшвщьеьсомдшзааоумаяшоуюоумаомхаыеыщоэзеущысжшощоэшы вщьаоиедмщиеысжютойеыыокеоэшмыахжааоваьуазьшаокехежщаод змеогшьнодшжавжшоножщваяшожаошйафеё
#
#
# step_number: 2000
# likelihood: 2528.81884765625
# едни ую уишите мокзанымюё ини бости мокзанымюё тевдт ь этого доожщемия вотокюё негво бкоситаты двокее удего ую уде дшенани бкауинымо и боньсите завдизанымюё жанн фа боднешмее сетуектое фашамие вькда хотя вомесмо я мисего ме ожещай
#
#
# step_number: 4000
# likelihood: 2541.565673828125
# евни ую уишите мокзанымюё ини бости мокзанымюё тедвт ь этого воожщемия дотокюё негдо бкоситаты вдокее увего ую уве вшенани бкауинымо и боньсите задвизанымюё жанн фа бовнешмее сетуектое фашамие дьква хотя домесмо я мисего ме ожещай
#
#
# MCMC is stopped: score hasn't been improved for 2000 steps

# %% [markdown]
# Расшифровка получилась так себе. Попробуем расшифровать сообщение "руками" как Шерлок Холмс. У меня получился вот такой ключ и соответствующая расшифровка:

# %%
custom_key = {
    "↹": " ",
    "↟": "и", 
    "⇒": "л", 
    "←": "е",
    "⇠": "c",
    "⇛": "о",
    "⇷": "п",
    "↤": "д",
    "↝": "н",
    "↷": "в", 
    "⇊": "ы",
    "↨": "т",
    "⇞": "ч",
    "↷": "в", 
    "⇯": "р",
    "⇰": "з",
    "⇴": "а",
    "↳": "м",
    "⇈": "ь", 
    "↾": "й", 
    "⇌": "к",
    "↙": "г", 
    "⇙": "у", 
    "↲": "б", 
    "⇸": "э",
    "↞": "я", 
    "⇆": "щ", 
    "↘": "х", 
    "⇏": "ю"
}

decoded_text = mcmc_decoder._decode_with_key(TEXT_TO_DECODE, custom_key)
decoded_text
# Out:
# 'еcли вы видите нормальный или почти нормальный текcт у этого cообщения который легко прочитать cкорее вcего вы вcе cделали правильно и получите макcимальный балл за поcледнее четвертое задание курcа хотя конечно я ничего не обещаю'

# %% [markdown]
# Оценим правдоподобие этой расшифровки:

# %%
decoded_text_stat = mcmc_decoder._count_text_statistics(decoded_text, mcmc_decoder.token_len)
score = mcmc_decoder._estimate_score(decoded_text_stat)
print(f"true answer likelihood: {score}")
# Out:
# true answer likelihood: 2519.170654296875

# %% [markdown]
# Правдоподобие настоящего ключа оказалось ниже, чем правдоподобие локального максимума, к которому сошелся алгоритм MCMC. Скорее всего, так получилось потому что текст для расшифровки короткий, и в нем содержится недостаточная информация для применения частотных методов.

# %% [markdown]
# ## Пункт 6. Возможные применения модели

# %% [markdown]
# Модель можно применять, например, в случае, когда необходимо прочитать файл в неизвестной кодировке.
